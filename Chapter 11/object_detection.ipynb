# %%
import boto3
import json

# %%
client = boto3.client('rekognition')
response = client.detect_labels(
    Image={
        'S3Object': {
            'Bucket': 'masteringmlsagemaker',
            'Name': 'ImageRecognition/chicago_boats.JPG'
        }
    },
    MaxLabels=5,
    MinConfidence=90
)

print(json.dumps(response, sort_keys=True, indent=4))
# Out:
# {
#     "LabelModelVersion": "2.0",
#     "Labels": [
#         {
#             "Confidence": 99.86528778076172,
#             "Instances": [
#                 {
#                     "BoundingBox": {
#                         "Height": 0.29408860206604004,
#                         "Left": 0.5391838550567627,
#                         "Top": 0.6836633682250977,
#                         "Width": 0.25161588191986084
#                     },
#                     "Confidence": 99.86528778076172
#                 },
#                 {
#                     "BoundingBox": {
#                         "Height": 0.11046414822340012,
#                         "Left": 0.23703880608081818,
#                         "Top": 0.6440696120262146,
#                         "Width": 0.07676628232002258
#                     },
#                     "Confidence": 99.5784912109375
#                 },
#                 {
#                     "BoundingBox": {
#                         "Height": 0.040305182337760925,
#                         "Left": 0.5480409860610962,
#                         "Top": 0.5758911967277527,
#                         "Width": 0.04315359890460968
#                     },
#                     "Confidence": 77.51519012451172
#                 }
#             ],
#             "Name": "Boat",
#             "Parents": []
#         },
#         {
#             "Confidence": 99.2927474975586,
#             "Instances": [],
#             "Name": "Watercraft",
#             "Parents": []
#         },
#         {
#             "Confidence": 95.6016616821289,
#             "Instances": [],
#             "Name": "Ferry",
#             "Parents": [
#                 {
#                     "Name": "Boat"
#                 }
#             ]
#         },
#         {
#             "Confidence": 94.45970153808594,
#             "Instances": [],
#             "Name": "Metropolis",
#             "Parents": []
#         },
#         {
#             "Confidence": 93.4244155883789,
#             "Instances": [
#                 {
#                     "BoundingBox": {
#                         "Height": 0.04357209801673889,
#                         "Left": 0.701830267906189,
#                         "Top": 0.8516684174537659,
#                         "Width": 0.017527872696518898
#                     },
#                     "Confidence": 93.4244155883789
#                 },
#                 {
#                     "BoundingBox": {
#                         "Height": 0.04150369018316269,
#                         "Left": 0.728438675403595,
#                         "Top": 0.8503196835517883,
#                         "Width": 0.01782326214015484
#                     },
#                     "Confidence": 83.21446228027344
#                 },
#                 {
#                     "BoundingBox": {
#                         "Height": 0.033978644758462906,
#                         "Left": 0.6294349431991577,
#                         "Top": 0.8507810831069946,
#                         "Width": 0.010845680721104145
#                     },
#                     "Confidence": 69.43881225585938
#                 },
#                 {
#                     "BoundingBox": {
#                         "Height": 0.038365740329027176,
#                         "Left": 0.9667714834213257,
#                         "Top": 0.6413958072662354,
#                         "Width": 0.013995165936648846
#                     },
#                     "Confidence": 67.07457733154297
#                 },
#                 {
#                     "BoundingBox": {
#                         "Height": 0.05711791664361954,
#                         "Left": 0.6207139492034912,
#                         "Top": 0.7452046871185303,
#                         "Width": 0.01596110314130783
#                     },
#                     "Confidence": 61.51835632324219
#                 }
#             ],
#             "Name": "Person",
#             "Parents": []
#         }
#     ],
#     "ResponseMetadata": {
#         "HTTPHeaders": {
#             "connection": "keep-alive",
#             "content-length": "1697",
#             "content-type": "application/x-amz-json-1.1",
#             "date": "Fri, 19 Apr 2019 02:40:25 GMT",
#             "x-amzn-requestid": "7c54f5de-624c-11e9-9e0f-a16a4e1ce384"
#         },
#         "HTTPStatusCode": 200,
#         "RequestId": "7c54f5de-624c-11e9-9e0f-a16a4e1ce384",
#         "RetryAttempts": 0
#     }
# }
