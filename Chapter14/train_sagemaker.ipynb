# %%
import boto3
import sagemaker
from sagemaker import get_execution_role

sess = sagemaker.Session()
role = get_execution_role()
container = sagemaker.amazon.amazon_estimator.get_image_uri('us-east-1', "xgboost", "latest")

s3_validation_data = 's3://mastering-ml-aws/chapter4/test-vector-csv/'
s3_train_data = 's3://mastering-ml-aws/chapter4/training-vector-csv/'
s3_output_location = 's3://mastering-ml-aws/chapter14/output/'

# %%
sagemaker_model = sagemaker.estimator.Estimator(container,
                                                role,
                                                train_instance_count=1,
                                                train_instance_type='ml.c4.4xlarge',
                                                train_volume_size=30,
                                                train_max_run=360000,
                                                input_mode='File',
                                                output_path=s3_output_location,
                                                sagemaker_session=sess)

# %%
sagemaker_model.set_hyperparameters(objective='binary:logistic',
                                    max_depth=5,
                                    eta=0.2,
                                    gamma=4,
                                    min_child_weight=6,
                                    subsample=0.7,
                                    silent=0,
                                    num_round=50)

# %%
from sagemaker.tuner import HyperparameterTuner, ContinuousParameter,IntegerParameter

tree_tuner = HyperparameterTuner(estimator=sagemaker_model, 
                                 objective_metric_name='validation:auc',
                                 max_jobs=10,
                                 max_parallel_jobs=3,
                                 hyperparameter_ranges={'lambda': ContinuousParameter(0, 1000),
                                                       'max_depth': IntegerParameter(3,7),
                                                       'eta':ContinuousParameter(0.1, 0.5)})

train_data = sagemaker.session.s3_input(s3_train_data, distribution='FullyReplicated',
                                        content_type='text/csv', s3_data_type='S3Prefix')

validation_data = sagemaker.session.s3_input(s3_validation_data, distribution='FullyReplicated',
                                             content_type='text/csv', s3_data_type='S3Prefix')

data_channels = {'train': train_data, 'validation': validation_data}

tree_tuner.fit(inputs=data_channels, logs=True)
# Out:
# INFO:sagemaker:Creating hyperparameter tuning job with name: xgboost-190407-1532

# %%
tree_tuner.best_training_job()
# Out:
# 'xgboost-190407-1532-005-0e830ada'

# %%
sess.sagemaker_client.describe_training_job(TrainingJobName=tree_tuner.best_training_job())
# Out:
# {'TrainingJobName': 'xgboost-190407-1532-005-0e830ada',
#  'TrainingJobArn': 'arn:aws:sagemaker:us-east-1:095585830284:training-job/xgboost-190407-1532-005-0e830ada',
#  'TuningJobArn': 'arn:aws:sagemaker:us-east-1:095585830284:hyper-parameter-tuning-job/xgboost-190407-1532',
#  'ModelArtifacts': {'S3ModelArtifacts': 's3://mastering-ml-aws/chapter14/output/xgboost-190407-1532-005-0e830ada/output/model.tar.gz'},
#  'TrainingJobStatus': 'Completed',
#  'SecondaryStatus': 'Completed',
#  'HyperParameters': {'_tuning_objective_metric': 'validation:auc',
#   'eta': '0.4630125855085939',
#   'gamma': '4',
#   'lambda': '29.566673825272677',
#   'max_depth': '7',
#   'min_child_weight': '6',
#   'num_round': '50',
#   'objective': 'binary:logistic',
#   'silent': '0',
#   'subsample': '0.7'},
#  'AlgorithmSpecification': {'TrainingImage': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest',
#   'TrainingInputMode': 'File',
#   'MetricDefinitions': [{'Name': 'train:mae',
#     'Regex': '.*\\[[0-9]+\\]#011train-mae:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#    {'Name': 'validation:auc',
#     'Regex': '.*\\[[0-9]+\\].*#011validation-auc:(\\S+)'},
#    {'Name': 'train:merror',
#     'Regex': '.*\\[[0-9]+\\]#011train-merror:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#    {'Name': 'train:auc',
#     'Regex': '.*\\[[0-9]+\\]#011train-auc:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#    {'Name': 'validation:mae',
#     'Regex': '.*\\[[0-9]+\\].*#011validation-mae:(\\S+)'},
#    {'Name': 'validation:error',
#     'Regex': '.*\\[[0-9]+\\].*#011validation-error:(\\S+)'},
#    {'Name': 'validation:merror',
#     'Regex': '.*\\[[0-9]+\\].*#011validation-merror:(\\S+)'},
#    {'Name': 'validation:logloss',
#     'Regex': '.*\\[[0-9]+\\].*#011validation-logloss:(\\S+)'},
#    {'Name': 'train:rmse',
#     'Regex': '.*\\[[0-9]+\\]#011train-rmse:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#    {'Name': 'train:logloss',
#     'Regex': '.*\\[[0-9]+\\]#011train-logloss:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#    {'Name': 'train:mlogloss',
#     'Regex': '.*\\[[0-9]+\\]#011train-mlogloss:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#    {'Name': 'validation:rmse',
#     'Regex': '.*\\[[0-9]+\\].*#011validation-rmse:(\\S+)'},
#    {'Name': 'validation:ndcg',
#     'Regex': '.*\\[[0-9]+\\].*#011validation-ndcg:(\\S+)'},
#    {'Name': 'train:error',
#     'Regex': '.*\\[[0-9]+\\]#011train-error:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#    {'Name': 'validation:mlogloss',
#     'Regex': '.*\\[[0-9]+\\].*#011validation-mlogloss:(\\S+)'},
#    {'Name': 'train:ndcg',
#     'Regex': '.*\\[[0-9]+\\]#011train-ndcg:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#    {'Name': 'train:map',
#     'Regex': '.*\\[[0-9]+\\]#011train-map:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#    {'Name': 'validation:map',
#     'Regex': '.*\\[[0-9]+\\].*#011validation-map:(\\S+)'}]},
#  'RoleArn': 'arn:aws:iam::095585830284:role/service-role/AmazonSageMaker-ExecutionRole-20181129T145112',
#  'InputDataConfig': [{'ChannelName': 'train',
#    'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix',
#      'S3Uri': 's3://mastering-ml-aws/chapter4/training-vector-csv/',
#      'S3DataDistributionType': 'FullyReplicated'}},
#    'ContentType': 'text/csv',
#    'CompressionType': 'None',
#    'RecordWrapperType': 'None'},
#   {'ChannelName': 'validation',
#    'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix',
#      'S3Uri': 's3://mastering-ml-aws/chapter4/test-vector-csv/',
#      'S3DataDistributionType': 'FullyReplicated'}},
#    'ContentType': 'text/csv',
#    'CompressionType': 'None',
#    'RecordWrapperType': 'None'}],
#  'OutputDataConfig': {'KmsKeyId': '',
#   'S3OutputPath': 's3://mastering-ml-aws/chapter14/output/'},
#  'ResourceConfig': {'InstanceType': 'ml.c4.4xlarge',
#   'InstanceCount': 1,
#   'VolumeSizeInGB': 30},
#  'StoppingCondition': {'MaxRuntimeInSeconds': 360000},
#  'CreationTime': datetime.datetime(2019, 4, 7, 15, 37, 15, 801000, tzinfo=tzlocal()),
#  'TrainingStartTime': datetime.datetime(2019, 4, 7, 15, 39, 13, 682000, tzinfo=tzlocal()),
#  'TrainingEndTime': datetime.datetime(2019, 4, 7, 15, 41, 51, 842000, tzinfo=tzlocal()),
#  'LastModifiedTime': datetime.datetime(2019, 4, 7, 15, 41, 51, 842000, tzinfo=tzlocal()),
#  'SecondaryStatusTransitions': [{'Status': 'Starting',
#    'StartTime': datetime.datetime(2019, 4, 7, 15, 37, 15, 801000, tzinfo=tzlocal()),
#    'EndTime': datetime.datetime(2019, 4, 7, 15, 39, 13, 682000, tzinfo=tzlocal()),
#    'StatusMessage': 'Preparing the instances for training'},
#   {'Status': 'Downloading',
#    'StartTime': datetime.datetime(2019, 4, 7, 15, 39, 13, 682000, tzinfo=tzlocal()),
#    'EndTime': datetime.datetime(2019, 4, 7, 15, 39, 38, 218000, tzinfo=tzlocal()),
#    'StatusMessage': 'Downloading input data'},
#   {'Status': 'Training',
#    'StartTime': datetime.datetime(2019, 4, 7, 15, 39, 38, 218000, tzinfo=tzlocal()),
#    'EndTime': datetime.datetime(2019, 4, 7, 15, 41, 45, 193000, tzinfo=tzlocal()),
#    'StatusMessage': 'Training image download completed. Training in progress.'},
#   {'Status': 'Uploading',
#    'StartTime': datetime.datetime(2019, 4, 7, 15, 41, 45, 193000, tzinfo=tzlocal()),
#    'EndTime': datetime.datetime(2019, 4, 7, 15, 41, 51, 842000, tzinfo=tzlocal()),
#    'StatusMessage': 'Uploading generated training model'},
#   {'Status': 'Completed',
#    'StartTime': datetime.datetime(2019, 4, 7, 15, 41, 51, 842000, tzinfo=tzlocal()),
#    'EndTime': datetime.datetime(2019, 4, 7, 15, 41, 51, 842000, tzinfo=tzlocal()),
#    'StatusMessage': 'Training job completed'}],
#  'FinalMetricDataList': [{'MetricName': 'validation:auc',
#    'Value': 0.6545940041542053,
#    'Timestamp': datetime.datetime(1970, 1, 18, 23, 50, 51, 700000, tzinfo=tzlocal())},
#   {'MetricName': 'train:auc',
#    'Value': 0.6541680097579956,
#    'Timestamp': datetime.datetime(1970, 1, 18, 23, 50, 51, 700000, tzinfo=tzlocal())}],
#  'EnableNetworkIsolation': False,
#  'EnableInterContainerTrafficEncryption': False,
#  'ResponseMetadata': {'RequestId': '7312d239-53cd-478d-8e4f-da4cdea5eb51',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '7312d239-53cd-478d-8e4f-da4cdea5eb51',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '4662',
#    'date': 'Sun, 07 Apr 2019 15:59:54 GMT'},
#   'RetryAttempts': 0}}

# %%
sess.sagemaker_client.describe_hyper_parameter_tuning_job(HyperParameterTuningJobName='xgboost-190407-1532')
# Out:
# {'HyperParameterTuningJobName': 'xgboost-190407-1532',
#  'HyperParameterTuningJobArn': 'arn:aws:sagemaker:us-east-1:095585830284:hyper-parameter-tuning-job/xgboost-190407-1532',
#  'HyperParameterTuningJobConfig': {'Strategy': 'Bayesian',
#   'HyperParameterTuningJobObjective': {'Type': 'Maximize',
#    'MetricName': 'validation:auc'},
#   'ResourceLimits': {'MaxNumberOfTrainingJobs': 10,
#    'MaxParallelTrainingJobs': 3},
#   'ParameterRanges': {'IntegerParameterRanges': [{'Name': 'max_depth',
#      'MinValue': '3',
#      'MaxValue': '7',
#      'ScalingType': 'Auto'}],
#    'ContinuousParameterRanges': [{'Name': 'lambda',
#      'MinValue': '0',
#      'MaxValue': '1000',
#      'ScalingType': 'Auto'},
#     {'Name': 'eta',
#      'MinValue': '0.1',
#      'MaxValue': '0.5',
#      'ScalingType': 'Auto'}],
#    'CategoricalParameterRanges': []},
#   'TrainingJobEarlyStoppingType': 'Off'},
#  'TrainingJobDefinition': {'StaticHyperParameters': {'_tuning_objective_metric': 'validation:auc',
#    'gamma': '4',
#    'min_child_weight': '6',
#    'num_round': '50',
#    'objective': 'binary:logistic',
#    'silent': '0',
#    'subsample': '0.7'},
#   'AlgorithmSpecification': {'TrainingImage': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest',
#    'TrainingInputMode': 'File',
#    'MetricDefinitions': [{'Name': 'train:mae',
#      'Regex': '.*\\[[0-9]+\\]#011train-mae:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#     {'Name': 'validation:auc',
#      'Regex': '.*\\[[0-9]+\\].*#011validation-auc:(\\S+)'},
#     {'Name': 'train:merror',
#      'Regex': '.*\\[[0-9]+\\]#011train-merror:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#     {'Name': 'train:auc',
#      'Regex': '.*\\[[0-9]+\\]#011train-auc:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#     {'Name': 'validation:mae',
#      'Regex': '.*\\[[0-9]+\\].*#011validation-mae:(\\S+)'},
#     {'Name': 'validation:error',
#      'Regex': '.*\\[[0-9]+\\].*#011validation-error:(\\S+)'},
#     {'Name': 'validation:merror',
#      'Regex': '.*\\[[0-9]+\\].*#011validation-merror:(\\S+)'},
#     {'Name': 'validation:logloss',
#      'Regex': '.*\\[[0-9]+\\].*#011validation-logloss:(\\S+)'},
#     {'Name': 'train:rmse',
#      'Regex': '.*\\[[0-9]+\\]#011train-rmse:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#     {'Name': 'train:logloss',
#      'Regex': '.*\\[[0-9]+\\]#011train-logloss:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#     {'Name': 'train:mlogloss',
#      'Regex': '.*\\[[0-9]+\\]#011train-mlogloss:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#     {'Name': 'validation:rmse',
#      'Regex': '.*\\[[0-9]+\\].*#011validation-rmse:(\\S+)'},
#     {'Name': 'validation:ndcg',
#      'Regex': '.*\\[[0-9]+\\].*#011validation-ndcg:(\\S+)'},
#     {'Name': 'train:error',
#      'Regex': '.*\\[[0-9]+\\]#011train-error:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#     {'Name': 'validation:mlogloss',
#      'Regex': '.*\\[[0-9]+\\].*#011validation-mlogloss:(\\S+)'},
#     {'Name': 'train:ndcg',
#      'Regex': '.*\\[[0-9]+\\]#011train-ndcg:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#     {'Name': 'train:map',
#      'Regex': '.*\\[[0-9]+\\]#011train-map:([-+]?[0-9]*\\.?[0-9]+([eE][-+]?[0-9]+)?).*'},
#     {'Name': 'validation:map',
#      'Regex': '.*\\[[0-9]+\\].*#011validation-map:(\\S+)'}]},
#   'RoleArn': 'arn:aws:iam::095585830284:role/service-role/AmazonSageMaker-ExecutionRole-20181129T145112',
#   'InputDataConfig': [{'ChannelName': 'train',
#     'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix',
#       'S3Uri': 's3://mastering-ml-aws/chapter4/training-vector-csv/',
#       'S3DataDistributionType': 'FullyReplicated'}},
#     'ContentType': 'text/csv'},
#    {'ChannelName': 'validation',
#     'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix',
#       'S3Uri': 's3://mastering-ml-aws/chapter4/test-vector-csv/',
#       'S3DataDistributionType': 'FullyReplicated'}},
#     'ContentType': 'text/csv'}],
#   'OutputDataConfig': {'S3OutputPath': 's3://mastering-ml-aws/chapter14/output/'},
#   'ResourceConfig': {'InstanceType': 'ml.c4.4xlarge',
#    'InstanceCount': 1,
#    'VolumeSizeInGB': 30},
#   'StoppingCondition': {'MaxRuntimeInSeconds': 360000},
#   'EnableNetworkIsolation': False,
#   'EnableInterContainerTrafficEncryption': False},
#  'HyperParameterTuningJobStatus': 'Completed',
#  'CreationTime': datetime.datetime(2019, 4, 7, 15, 32, 59, 788000, tzinfo=tzlocal()),
#  'HyperParameterTuningEndTime': datetime.datetime(2019, 4, 7, 15, 49, 56, 924000, tzinfo=tzlocal()),
#  'LastModifiedTime': datetime.datetime(2019, 4, 7, 15, 49, 56, 924000, tzinfo=tzlocal()),
#  'TrainingJobStatusCounters': {'Completed': 10,
#   'InProgress': 0,
#   'RetryableError': 0,
#   'NonRetryableError': 0,
#   'Stopped': 0},
#  'ObjectiveStatusCounters': {'Succeeded': 10, 'Pending': 0, 'Failed': 0},
#  'BestTrainingJob': {'TrainingJobName': 'xgboost-190407-1532-005-0e830ada',
#   'TrainingJobArn': 'arn:aws:sagemaker:us-east-1:095585830284:training-job/xgboost-190407-1532-005-0e830ada',
#   'CreationTime': datetime.datetime(2019, 4, 7, 15, 37, 15, tzinfo=tzlocal()),
#   'TrainingStartTime': datetime.datetime(2019, 4, 7, 15, 39, 13, tzinfo=tzlocal()),
#   'TrainingEndTime': datetime.datetime(2019, 4, 7, 15, 41, 51, tzinfo=tzlocal()),
#   'TrainingJobStatus': 'Completed',
#   'TunedHyperParameters': {'eta': '0.4630125855085939',
#    'lambda': '29.566673825272677',
#    'max_depth': '7'},
#   'FinalHyperParameterTuningJobObjectiveMetric': {'MetricName': 'validation:auc',
#    'Value': 0.6545940041542053},
#   'ObjectiveStatus': 'Succeeded'},
#  'ResponseMetadata': {'RequestId': 'fb18883c-a5c6-42a4-a012-faa3beedf83d',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'fb18883c-a5c6-42a4-a012-faa3beedf83d',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '4519',
#    'date': 'Sun, 07 Apr 2019 16:00:04 GMT'},
#   'RetryAttempts': 0}}
